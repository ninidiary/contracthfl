# %%
# -*- coding: utf-8 -*-

import os
import numpy as np
import time
import argparse
import sys
import csv
import copy
import pandas as pd


import math
from math import ceil
from random import Random

import torch
import torch.distributed as dist
import torch.utils.data.distributed
import torch.nn as nn
import torch.nn.functional as F
from torch.multiprocessing import Process
import torchvision
from torchvision import datasets, transforms
import torch.backends.cudnn as cudnn
import torchvision.models as models

from distoptim import FedProx, FedNova
#import util_v4 as util
from models import *

def args_parser():
    parser = argparse.ArgumentParser()
    parser.add_argument('--exp_name','-n', 
                        default="test_fednova", 
                        type=str, 
                        help='experiment name, used for saving results')
    parser.add_argument('--backend',
                        default="nccl",
                        type=str,
                        help='background name')
    parser.add_argument('--model', 
                        default="VGG", 
                        type=str, 
                        help='neural network model')
    parser.add_argument('--NIID',
                        action='store_true',
                        default = True,
                        help='whether the dataset is non-iid or not')
    parser.add_argument('--alpha', 
                        default=0.2,  # default 0.2
                        type=float, 
                        help='control the non-iidness of dataset')
    parser.add_argument('--gmf', 
                        default=0, 
                        type=float, 
                        help='global (server) momentum factor')
    parser.add_argument('--lr', 
                        default=0.01, 
                        type=float, 
                        help='client learning rate')
    parser.add_argument('--momentum', 
                        default=0.0, 
                        type=float, 
                        help='local (client) momentum factor')
    parser.add_argument('--bs', 
                        default=16, # default 32
                        type=int, 
                        help='batch size on each worker/client')
    parser.add_argument('--rounds', 
                        default=10, # default 200
                        type=int, 
                        help='total coommunication rounds')
    parser.add_argument('--localE', 
                        default=20, 
                        type=int, 
                        help='number of local epochs')
    parser.add_argument('--meanE', 
                        default=10,
                        type=int, 
                        help='average number of local epochs')
    parser.add_argument('--print_freq', 
                        default=100, 
                        type=int, 
                        help='print info frequency')
    parser.add_argument('--size', 
                        default=8,  # default 16
                        type=int, 
                        help='number of local workers')
# =============================================================================
#     parser.add_argument('--rank', 
#                         default=0, 
#                         type=int, 
#                         help='the rank of worker')
# =============================================================================
    parser.add_argument('--seed', 
                        default=1, 
                        type=int, 
                        help='random seed')
    parser.add_argument('--save', '-s', 
                        action='store_true', 
                        help='whether save the training results')
    parser.add_argument('--p', '-p', 
                        action='store_true', 
                        help='whether the dataset is partitioned or not')
    parser.add_argument('--pattern',
                        type=str, 
                        help='pattern of local steps')
    parser.add_argument('--optimizer', 
                        default='fednova', 
                        type=str, 
                        help='optimizer name')
    parser.add_argument('--initmethod',
                        default='tcp://h0:22000',
                        type=str,
                        help='init method')
    parser.add_argument('--mu', 
                        default=1, 
                        type=float, 
                        help='mu parameter in fedprox')
    parser.add_argument('--savepath',
                        default='./results/',
                        type=str,
                        help='directory to save exp results')
    parser.add_argument('--datapath',
                        default='./data2/',
                        type=str,
                        help='directory to load data')
    args = parser.parse_known_args()[0]
    return args

def update_learning_rate(optimizer, epoch, target_lr):
    """
    1) Decay learning rate exponentially (epochs 30, 60, 80)
    ** note: target_lr is the reference learning rate from which to scale down
    """
    if epoch == int(args.rounds / 2):
        lr = target_lr/10
        print('Updating learning rate to {}'.format(lr))
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

    if epoch == int(args.rounds * 0.75):
        lr = target_lr/100
        print('Updating learning rate to {}'.format(lr))
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
class Meter(object):
    """ Computes and stores the average, variance, and current value """

    def __init__(self, init_dict=None, ptag='Time', stateful=False,
                 csv_format=True):
        """
        :param init_dict: Dictionary to initialize meter values
        :param ptag: Print tag used in __str__() to identify meter
        :param stateful: Whether to store value history and compute MAD
        """
        self.reset()
        self.ptag = ptag
        self.value_history = None
        self.stateful = stateful
        if self.stateful:
            self.value_history = []
        self.csv_format = csv_format
        if init_dict is not None:
            for key in init_dict:
                try:
                    # TODO: add type checking to init_dict values
                    self.__dict__[key] = init_dict[key]
                except Exception:
                    print('(Warning) Invalid key {} in init_dict'.format(key))

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
        self.std = 0
        self.sqsum = 0
        self.mad = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        self.sqsum += (val ** 2) * n
        if self.count > 1:
            self.std = ((self.sqsum - (self.sum ** 2) / self.count)
                        / (self.count - 1)
                        ) ** 0.5
        if self.stateful:
            self.value_history.append(val)
            mad = 0
            for v in self.value_history:
                mad += abs(v - self.avg)
            self.mad = mad / len(self.value_history)

    def __str__(self):
        if self.csv_format:
            if self.stateful:
                return str('{dm.val:.3f},{dm.avg:.3f},{dm.mad:.3f}'
                           .format(dm=self))
            else:
                return str('{dm.val:.3f},{dm.avg:.3f},{dm.std:.3f}'
                           .format(dm=self))
        else:
            if self.stateful:
                return str(self.ptag) + \
                       str(': {dm.val:.3f} ({dm.avg:.3f} +- {dm.mad:.3f})'
                           .format(dm=self))
            else:
                return str(self.ptag) + \
                       str(': {dm.val:.3f} ({dm.avg:.3f} +- {dm.std:.3f})'
                           .format(dm=self))
   

class Partition(object):
    """ Dataset-like object, but only access a subset of it. """

    def __init__(self, data, index):
        self.data = data
        self.index = index

    def __len__(self):
        return len(self.index)

    def __getitem__(self, index):
        data_idx = self.index[index]
        return self.data[data_idx]

class DataPartitioner(object):
    """ Partitions a dataset into different chuncks. """
    def __init__(self, data, sizes=[0.7, 0.2, 0.1], seed=1234, isNonIID=False, alpha=0, dataset=None):
        self.data = data
        self.dataset = dataset
        if isNonIID:
            print('Dataset is Non IID!')
            self.partitions, self.ratio = self.__getDirichletData__(data, sizes, seed, alpha)

        else:
            print('Dataset is IID!')
            self.partitions = [] 
            self.ratio = sizes
            rng = Random() 
            rng.seed(seed) 
            data_len = len(data) 
            indexes = [x for x in range(0, data_len)] 
            rng.shuffle(indexes) 
             
     
            for frac in sizes: 
                part_len = int(frac * data_len)
                self.partitions.append(indexes[0:part_len])
                indexes = indexes[part_len:]

        

    def use(self, partition):
        return Partition(self.data, self.partitions[partition])

    def __getNonIIDdata__(self, data, sizes, seed, alpha):
        labelList = data.train_labels
        rng = Random()
        rng.seed(seed)
        a = [(label, idx) for idx, label in enumerate(labelList)]
        # Same Part
        labelIdxDict = dict()
        for label, idx in a:
            labelIdxDict.setdefault(label,[])
            labelIdxDict[label].append(idx)
        labelNum = len(labelIdxDict)
        labelNameList = [key for key in labelIdxDict]
        labelIdxPointer = [0] * labelNum
        # sizes = number of nodes
        partitions = [list() for i in range(len(sizes))]
        eachPartitionLen= int(len(labelList)/len(sizes))
        # majorLabelNumPerPartition = ceil(labelNum/len(partitions))
        majorLabelNumPerPartition = 2
        basicLabelRatio = alpha

        interval = 1
        labelPointer = 0

        #basic part
        for partPointer in range(len(partitions)):
            requiredLabelList = list()
            for _ in range(majorLabelNumPerPartition):
                requiredLabelList.append(labelPointer)
                labelPointer += interval
                if labelPointer > labelNum - 1:
                    labelPointer = interval
                    interval += 1
            for labelIdx in requiredLabelList:
                start = labelIdxPointer[labelIdx]
                idxIncrement = int(basicLabelRatio*len(labelIdxDict[labelNameList[labelIdx]]))
                partitions[partPointer].extend(labelIdxDict[labelNameList[labelIdx]][start:start+ idxIncrement])
                labelIdxPointer[labelIdx] += idxIncrement

        #random part
        remainLabels = list()
        for labelIdx in range(labelNum):
            remainLabels.extend(labelIdxDict[labelNameList[labelIdx]][labelIdxPointer[labelIdx]:])
        rng.shuffle(remainLabels)
        for partPointer in range(len(partitions)):
            idxIncrement = eachPartitionLen - len(partitions[partPointer])
            partitions[partPointer].extend(remainLabels[:idxIncrement])
            rng.shuffle(partitions[partPointer])
            remainLabels = remainLabels[idxIncrement:]

        return partitions
    
    def __getDirichletData__(self, data, psizes, seed, alpha):
        n_nets = len(psizes)
        K = 10
        # labelList = np.array(data.train_labels) 修改成下面一行
        labelList = np.array(data.targets)
        min_size = 0
        N = len(labelList)
        np.random.seed(2020)

        net_dataidx_map = {}
        while min_size < K:
            idx_batch = [[] for _ in range(n_nets)]
            # for each class in the dataset
            for k in range(K):
                idx_k = np.where(labelList == k)[0]
                np.random.shuffle(idx_k)
                proportions = np.random.dirichlet(np.repeat(alpha, n_nets)) # alpha 越大越接近iid
                ## Balance
                proportions = np.array([p*(len(idx_j)<N/n_nets) for p,idx_j in zip(proportions,idx_batch)])
                proportions = proportions/proportions.sum()
                proportions = (np.cumsum(proportions)*len(idx_k)).astype(int)[:-1]
                idx_batch = [idx_j + idx.tolist() for idx_j,idx in zip(idx_batch,np.split(idx_k,proportions))]
                min_size = min([len(idx_j) for idx_j in idx_batch])

        for j in range(n_nets):
            np.random.shuffle(idx_batch[j])
            net_dataidx_map[j] = idx_batch[j]
            
        net_cls_counts = {}

        for net_i, dataidx in net_dataidx_map.items():
            unq, unq_cnt = np.unique(labelList[dataidx], return_counts=True)
            tmp = {unq[i]: unq_cnt[i] for i in range(len(unq))}
            net_cls_counts[net_i] = tmp
        # print('Data statistics: %s' % str(net_cls_counts))

        local_sizes = []
        for i in range(n_nets):
            local_sizes.append(len(net_dataidx_map[i]))
        local_sizes = np.array(local_sizes)
        weights = local_sizes/np.sum(local_sizes)
        # print(weights)

        return idx_batch, weights

def partition_dataset(rank, size, args):
    print('==> load train data')
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])
    trainset = torchvision.datasets.CIFAR10(root=args.datapath, 
                                            train=True, 
                                            download=True, 
                                            transform=transform_train)
    
    partition_sizes = [1.0 / size for _ in range(size)]
    partition = DataPartitioner(trainset, partition_sizes, isNonIID=args.NIID, alpha=args.alpha)
    ratio = partition.ratio
    partition = partition.use(rank)
    train_loader = torch.utils.data.DataLoader(partition, 
                                            batch_size=args.bs, 
                                            shuffle=True, 
                                            pin_memory=True)

    print('==> load test data')
    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])
    testset = torchvision.datasets.CIFAR10(root=args.datapath, 
                                        train=False, 
                                        download=True, 
                                        transform=transform_test)
    test_loader = torch.utils.data.DataLoader(testset, 
                                            batch_size=64, 
                                            shuffle=False, 
                                            num_workers=size)

    # You can add more datasets here
    return train_loader, test_loader, ratio

def select_model(num_class, args):
    if args.model == 'VGG':
        model = vgg11()

    # You can add more models here
    return model

def comp_accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res 

def train(model, criterion, optimizer, loader, epoch):

    model.train()

    losses = Meter(ptag='Loss')
    top1 = Meter(ptag='Prec@1')
    for batch_idx, (data, target) in enumerate(loader):
        # data loading
        data = data.cuda(non_blocking = True)
        target = target.cuda(non_blocking = True)

        # forward pass
        output = model(data)
        loss = criterion(output, target)

        # backward pass
        loss.backward()
        
        # total_norm = 0.0
        # for param in model.parameters():
        #     if param.grad is not None:
        #         param_norm = param.grad.data.norm(2)  # L2范数
        #         total_norm += param_norm.item() ** 2
        # grad_norm = total_norm ** 0.5
        # grad_norms.append(grad_norm)  # 记录梯度范数

        # gradient step
        optimizer.step()
        optimizer.zero_grad()

        # write log files
        train_acc = comp_accuracy(output, target)
        

        losses.update(loss.item(), data.size(0))
        top1.update(train_acc[0].item(), data.size(0))
    
    return model.state_dict()

def average_weights(w):
    """
    Returns the average of the weights.
    """
    w_avg = copy.deepcopy(w[0])
    for key in w_avg.keys():
        for i in range(1, len(w)):
            w_avg[key] += w[i][key]
        w_avg[key] = torch.div(w_avg[key], len(w))
    return w_avg       

def evaluate(model, test_loader):
    model.eval()
    top1 = Meter(ptag='Acc')
    loss=0
    with torch.no_grad():
        for data, target in test_loader:
            data = data.cuda(non_blocking = True)
            target = target.cuda(non_blocking = True)
            outputs = model(data)
            acc1 = comp_accuracy(outputs, target)
            top1.update(acc1[0].item(), data.size(0))
            batch_loss = criterion(outputs, target)
            loss += batch_loss.item()

    return top1.avg, loss

# # yn add 
# def compute_global_grad_norm(model, dataloader, criterion):
#     """
#     计算全局模型的梯度L2范数
#     Args:
#         model: 全局模型
#         dataloader: 用于计算梯度的数据加载器（通常是一个全局验证集）
#         criterion: 损失函数
#     Returns:
#         grad_norm: 全局梯度范数 (float)
#     """
#     model.eval()  # 注意：这里用eval模式，但需要临时允许梯度计算
#     total_norm = 0.0
    
#     # 临时启用梯度计算（即使模型处于eval模式）
#     with torch.set_grad_enabled(True):
#         for data, target in dataloader:
#             data = data.cuda(non_blocking=True)
#             target = target.cuda(non_blocking=True)
            
#             # 清零梯度
#             model.zero_grad()
            
#             # 前向传播和反向传播
#             outputs = model(data)
#             loss = criterion(outputs, target)
#             loss.backward()  # 计算梯度
            
#             # 累加所有参数的梯度范数平方
#             for param in model.parameters():
#                 if param.grad is not None:
#                     total_norm += param.grad.data.norm(2).item() ** 2
    
#     return total_norm ** 0.5  # 返回L2范数

def generate_random_array(size, mean, lower_bound, upper_bound):
    # Generate a random array within the specified range
    random_array = np.random.randint(lower_bound, upper_bound + 1, size)
    
    # Calculate the current mean of the array
    current_mean = np.mean(random_array)
    
    # Adjust the array to have the desired mean
    adjustment_factor = mean / current_mean
    adjusted_array = np.clip(random_array * adjustment_factor, lower_bound, upper_bound).astype(int)
    
    # Ensure that the mean is as close to the target as possible
    while abs(np.mean(adjusted_array) - mean) > 0.1:  # Adjust the threshold as needed
        random_array = np.random.randint(lower_bound, upper_bound + 1, size)
        current_mean = np.mean(random_array)
        adjustment_factor = mean / current_mean
        adjusted_array = np.clip(random_array * adjustment_factor, lower_bound, upper_bound).astype(int)

    return adjusted_array

# gpt 版本
def get_Fnw(global_model, train_loader):
    global_model.train()  # 确保模型在评估模式（关闭Dropout/BatchNorm）
    total_grad = None
    total_samples = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        images.requires_grad_(True)
        # 前向传播并计算梯度
        global_model.zero_grad()
        target_pred = global_model(images)
        loss = criterion(target_pred, labels)
        gradients = torch.autograd.grad(loss, global_model.parameters(), create_graph=False)

        # 扁平化并累加梯度
        batch_grad = torch.cat([g.flatten() for g in gradients])
        if total_grad is None:
            total_grad = batch_grad
        else:
            total_grad += batch_grad
        total_samples += 1

    # 计算平均梯度
    mean_grad = total_grad / total_samples
    return mean_grad.unsqueeze(0)  # 保持与原代码输出形状一致

def get_betan(rank):
    Fnw=means[rank] #mean_rank = get_Fnw(global_model, train_loader), means.append(mean_rank)
    # x = Fnw-Fw
    # x_norm = x.norm(dim=1, p=1)
    # Fw_norm = Fw.norm(dim=1, p=1)
    # beta = x_norm/Fw_norm
    
    Fnw_norm = Fnw.norm(dim=1, p=2)
    Fw_norm = Fw.norm(dim=1, p=2)
    beta = Fnw_norm/Fw_norm -1
    
    beta = beta.detach().cpu().numpy()
    return beta[0]

# %%
# # yn new:
# def get_Fnw(global_model, train_loader):
#     gradients = []
#     for batch_idx, (images, labels) in enumerate(train_loader):
#         images, labels = images.to(device), labels.to(device)
#         #print(images.size(), labels.size())
#         images.requires_grad = True

#         global_model.zero_grad()
#         target_pred = global_model(images)
#         y = criterion(target_pred, labels)
#         dy = torch.autograd.grad(y, global_model.parameters())
#         target_grad = torch.cat([g.detach().clone().reshape(1, -1) for g in dy], 1).reshape(1, -1)
#         target_grad.requires_grad = True
#         target_grad = target_grad.to(device)
#         #grad_norm = torch.norm(target_grad).detach().cpu().numpy()

#         gradients.append(target_grad)
#     mean = torch.mean(torch.stack(gradients), dim=0)
#     #print(mean.size())
#     return mean

# def get_betan(rank):
#     Fnw=means[rank] #mean_rank = get_Fnw(global_model, train_loader), means.append(mean_rank)
#     Fnw_norm = Fnw.norm(dim=1, p=2)
#     Fw_norm = Fw.norm(dim=1, p=2)
    
#     beta = Fnw_norm/Fw_norm
#     beta = beta.detach().cpu().numpy()
#     return beta[0]

# %% [markdown]
# # split main fuc

# %%
args = args_parser()
if not os.path.exists('./log/'+args.exp_name):
    os.makedirs('./log/'+args.exp_name) # yn modify from mkdir to makedirs
#rank = args.rank#the rank of worker,0,because distributed runing, each file has a client id
size = args.size #number of local workers,8
device = 'cuda:0'

torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)
torch.backends.cudnn.deterministic = True

global_model = select_model(10, args).to(device)#10 class classification
global_weights = global_model.state_dict()
algorithms = {
    'fedavg': FedProx, # mu = 0
    'fedprox': FedProx,
    # 'scaffold': Scaffold,
    'fednova': FedNova,
    # 'fednova_vr':FedNovaVR,
}
selected_opt = algorithms[args.optimizer]
epochs_array = generate_random_array(size, mean=args.meanE, lower_bound=1, upper_bound=args.localE)
# epochs_array = np.array([args.meanE]*args.size)
print(epochs_array)
# test_accs,test_losses=[],[]
test_accs,test_losses, test_Fw_norm=[],[],[]
betas = np.zeros([args.rounds,args.size]) 
results = pd.DataFrame()
for rnd in range(args.rounds): # 轮次 200 rounds
    start = time.time()
    global_model.train()
    local_weights=[]
    means =[]
    for rank in range(args.size): # 遍历所有客户端
        train_loader, test_loader, DataRatios = partition_dataset(rank, size, args)
        local_epochs = epochs_array[rank]
        print('global round:{:d}, client id={:d}, localE={:d}'.format(rnd, rank, local_epochs))

        local_model = copy.deepcopy(global_model)
        criterion = nn.CrossEntropyLoss().to(device)
        optimizer = selected_opt(local_model.parameters(),
                         lr=args.lr,
                         gmf=args.gmf,
                         mu=args.mu,
                         ratio=DataRatios[rank],
                         momentum=args.momentum,
                         nesterov = False,
                         weight_decay=1e-4)

        update_learning_rate(optimizer, rnd, args.lr)


        for t in range(local_epochs): # epoch 96
            w =train(local_model, criterion, optimizer, train_loader, t)
            local_weights.append(copy.deepcopy(w))
        
    
    # yn add:  
        mean_rank = get_Fnw(global_model, train_loader) 
        means.append(mean_rank)
    Fw = torch.mean(torch.stack(means), dim=0) #每轮一个
    Fw_norm = Fw.norm(dim=1, p=2)
    test_Fw_norm.append(Fw_norm)
    Fw_norm_values = [tensor.item() for tensor in test_Fw_norm]
    for rank in range(args.size):
        beta = get_betan(rank)  # 使用当前轮的 Fw 和 means[rank]
        betas[rnd, rank] = beta #
    # yn add end
    # torch.save(local_weights,'./test_r200_c8_e5_10/local_weights/'+str(rnd)+'.pth')
    global_weights = average_weights(local_weights)
    global_model.load_state_dict(global_weights)
    test_acc, test_loss = evaluate(global_model, test_loader)
    print('global round:{:d}, test_acc={:.2f}, test_loss={:.4f}'.format(rnd, test_acc, test_loss))
    test_accs.append(test_acc)
    test_losses.append(test_loss)
    end = time.time()
    cost_time = end -start
    print(f'Round {rnd} takes {cost_time} s.')
    ## save model
    file_name = f'./result06154/exp43_{args.optimizer}_{args.model}_{args.NIID}_alpha{args.alpha}_lr{args.lr}_bs{args.bs}_epoch{args.meanE}_{args.localE}_size{args.size}'
    torch.save(global_model.state_dict(), f'{file_name}_model.pth')
    print(f'saved round {rnd} model gradient!')
    ## save results
    results = pd.DataFrame()
    results['round'] = list(range(len(test_accs)))
    results['acc'] =test_accs
    results['loss'] =test_losses
    results['Fw_norm'] =Fw_norm_values
    results.to_csv(file_name+'.csv', index = False)
    pd.DataFrame(betas).to_csv(file_name+'_beta.csv', index=False)
# results['round'] = list(range(len(test_accs)))
# results['acc'] =test_accs
# results['loss'] =test_losses
# results['Fw_norm'] =Fw_norm_values
# file_name = f'./result/{args.optimizer}_{args.NIID}_alpha{args.alpha}_lr{args.lr}_bs{args.bs}_rounds{len(test_accs)}_epoch{args.meanE}_{args.localE}_size{args.size}.csv'
# results.to_csv(file_name, index = False)
# pd.DataFrame(betas).to_csv(f'{file_name}_beta.csv', index=False)



# yn comment starts
    # # save results
    # csvfile = open('./test_r200_c8_e5_10/'+args.exp_name+'/epoch_acc_loss.csv',"a",newline = "")      #w是覆盖形写入，a是追加写入
    # writer = csv.writer(csvfile)
    # writer.writerow([rnd, test_acc, test_loss])
    # csvfile.close()
# yn comment ends
# Out:
# [5 5 5 5 5 5 5 5]
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=0, localE=5
# /root/autodl-tmp/AAA_yn_hfl/distoptim/FedNova.py:117: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha = 1) (Triggered internally at /pytorch/torch/csrc/utils/python_arg_parser.cpp:1691.)
#   d_p.add_(weight_decay, p.data)
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:0, client id=7, localE=5
# global round:0, test_acc=10.00, test_loss=361.3256
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:1, client id=7, localE=5
# global round:1, test_acc=10.01, test_loss=361.1136
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:2, client id=7, localE=5
# global round:2, test_acc=10.84, test_loss=360.8542
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:3, client id=7, localE=5
# global round:3, test_acc=12.02, test_loss=360.5294
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:4, client id=7, localE=5
# global round:4, test_acc=17.60, test_loss=360.1069
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:5, client id=7, localE=5
# global round:5, test_acc=19.27, test_loss=359.4476
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:6, client id=7, localE=5
# global round:6, test_acc=22.09, test_loss=358.2857
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:7, client id=7, localE=5
# global round:7, test_acc=22.42, test_loss=355.2730
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:8, client id=7, localE=5
# global round:8, test_acc=21.75, test_loss=344.0731
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:9, client id=7, localE=5
# global round:9, test_acc=22.39, test_loss=330.3283
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:10, client id=7, localE=5
# global round:10, test_acc=21.25, test_loss=322.4170
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:11, client id=7, localE=5
# global round:11, test_acc=21.53, test_loss=319.7456
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:12, client id=7, localE=5
# global round:12, test_acc=22.19, test_loss=314.6943
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:13, client id=7, localE=5
# global round:13, test_acc=23.66, test_loss=311.1342
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:14, client id=7, localE=5
# global round:14, test_acc=24.11, test_loss=306.2893
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:15, client id=7, localE=5
# global round:15, test_acc=24.90, test_loss=301.7217
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:16, client id=7, localE=5
# global round:16, test_acc=26.35, test_loss=298.3862
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:17, client id=7, localE=5
# global round:17, test_acc=27.92, test_loss=295.0166
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:18, client id=7, localE=5
# global round:18, test_acc=28.20, test_loss=292.4496
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:19, client id=7, localE=5
# global round:19, test_acc=29.49, test_loss=289.5234
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:20, client id=7, localE=5
# global round:20, test_acc=30.51, test_loss=285.7510
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:21, client id=7, localE=5
# global round:21, test_acc=31.34, test_loss=282.9223
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:22, client id=7, localE=5
# global round:22, test_acc=31.95, test_loss=281.6940
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:23, client id=7, localE=5
# global round:23, test_acc=32.86, test_loss=278.8789
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:24, client id=7, localE=5
# global round:24, test_acc=32.97, test_loss=277.9934
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:25, client id=7, localE=5
# global round:25, test_acc=33.53, test_loss=274.0743
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:26, client id=7, localE=5
# global round:26, test_acc=34.30, test_loss=271.9096
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:27, client id=7, localE=5
# global round:27, test_acc=34.33, test_loss=271.0433
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:28, client id=7, localE=5
# global round:28, test_acc=35.30, test_loss=267.2278
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:29, client id=7, localE=5
# global round:29, test_acc=36.20, test_loss=265.3750
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:30, client id=7, localE=5
# global round:30, test_acc=36.49, test_loss=263.1672
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:31, client id=7, localE=5
# global round:31, test_acc=36.84, test_loss=263.1504
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:32, client id=7, localE=5
# global round:32, test_acc=36.59, test_loss=262.0228
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:33, client id=7, localE=5
# global round:33, test_acc=37.75, test_loss=258.5327
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:34, client id=7, localE=5
# global round:34, test_acc=38.19, test_loss=255.6125
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:35, client id=7, localE=5
# global round:35, test_acc=38.58, test_loss=255.0283
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:36, client id=7, localE=5
# global round:36, test_acc=39.11, test_loss=251.7692
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:37, client id=7, localE=5
# global round:37, test_acc=39.59, test_loss=250.1872
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:38, client id=7, localE=5
# global round:38, test_acc=40.56, test_loss=247.0979
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:39, client id=7, localE=5
# global round:39, test_acc=40.96, test_loss=246.1093
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:40, client id=7, localE=5
# global round:40, test_acc=41.16, test_loss=243.4169
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:41, client id=7, localE=5
# global round:41, test_acc=41.87, test_loss=240.3024
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:42, client id=7, localE=5
# global round:42, test_acc=42.15, test_loss=239.4658
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:43, client id=7, localE=5
# global round:43, test_acc=42.02, test_loss=238.9516
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:44, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:44, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:44, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:44, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:44, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:44, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:44, client id=6, localE=5
# Dataset is IID!
# ==> load test data
# global round:44, client id=7, localE=5
# global round:44, test_acc=42.77, test_loss=236.1481
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:45, client id=7, localE=5
# global round:45, test_acc=43.69, test_loss=232.8292
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:46, client id=7, localE=5
# global round:46, test_acc=43.88, test_loss=232.4302
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:47, client id=7, localE=5
# global round:47, test_acc=44.35, test_loss=230.3760
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:48, client id=7, localE=5
# global round:48, test_acc=45.08, test_loss=228.6297
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:49, client id=7, localE=5
# global round:49, test_acc=45.52, test_loss=227.7270
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:50, client id=7, localE=5
# global round:50, test_acc=45.44, test_loss=225.6050
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:51, client id=7, localE=5
# global round:51, test_acc=46.26, test_loss=224.8793
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:52, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:52, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:52, client id=2, localE=5
# Dataset is IID!
# ==> load test data
# global round:52, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:52, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:52, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:52, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:52, client id=7, localE=5
# global round:52, test_acc=46.27, test_loss=223.5830
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:53, client id=7, localE=5
# global round:53, test_acc=46.66, test_loss=221.7791
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:54, client id=7, localE=5
# global round:54, test_acc=46.95, test_loss=220.3399
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:55, client id=7, localE=5
# global round:55, test_acc=47.31, test_loss=219.0845
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:56, client id=7, localE=5
# global round:56, test_acc=48.12, test_loss=217.8948
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:57, client id=7, localE=5
# global round:57, test_acc=48.55, test_loss=215.9785
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:58, client id=7, localE=5
# global round:58, test_acc=48.72, test_loss=214.2610
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:59, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:59, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:59, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ...
# global round:74, test_acc=55.54, test_loss=192.2609
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=0, localE=5
# Updating learning rate to 0.001
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=1, localE=5
# Updating learning rate to 0.001
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=2, localE=5
# Updating learning rate to 0.001
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=3, localE=5
# Updating learning rate to 0.001
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=4, localE=5
# Updating learning rate to 0.001
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=5, localE=5
# Updating learning rate to 0.001
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=6, localE=5
# Updating learning rate to 0.001
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:75, client id=7, localE=5
# Updating learning rate to 0.001
# global round:75, test_acc=56.22, test_loss=188.4448
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:76, client id=7, localE=5
# global round:76, test_acc=56.46, test_loss=188.9854
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:77, client id=7, localE=5
# global round:77, test_acc=56.56, test_loss=187.9056
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:78, client id=7, localE=5
# global round:78, test_acc=56.40, test_loss=187.9881
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:79, client id=7, localE=5
# global round:79, test_acc=57.05, test_loss=186.0727
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:80, client id=7, localE=5
# global round:80, test_acc=57.19, test_loss=184.8450
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:81, client id=7, localE=5
# global round:81, test_acc=57.46, test_loss=185.0779
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:82, client id=7, localE=5
# global round:82, test_acc=57.91, test_loss=183.1954
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:83, client id=7, localE=5
# global round:83, test_acc=58.21, test_loss=181.3538
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:84, client id=7, localE=5
# global round:84, test_acc=58.28, test_loss=179.9569
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:85, client id=7, localE=5
# global round:85, test_acc=58.61, test_loss=179.0473
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:86, client id=7, localE=5
# global round:86, test_acc=59.13, test_loss=178.6625
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:87, client id=7, localE=5
# global round:87, test_acc=59.50, test_loss=177.2309
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:88, client id=7, localE=5
# global round:88, test_acc=59.64, test_loss=176.6184
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:89, client id=7, localE=5
# global round:89, test_acc=59.97, test_loss=174.4461
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:90, client id=7, localE=5
# global round:90, test_acc=60.13, test_loss=173.1068
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:91, client id=7, localE=5
# global round:91, test_acc=60.17, test_loss=172.7100
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:92, client id=7, localE=5
# global round:92, test_acc=60.54, test_loss=171.4499
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=3, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=4, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=5, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=6, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:93, client id=7, localE=5
# global round:93, test_acc=60.43, test_loss=171.1567
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:94, client id=0, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:94, client id=1, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:94, client id=2, localE=5
# ==> load train data
# Dataset is IID!
# ==> load test data
# global round:94, client id=3, localE=5
# ==> load train data

# %%
results['round'] = list(range(len(test_accs)))
results['acc'] =test_accs
results['loss'] =test_losses
results['Fw_norm'] =Fw_norm_values
file_name = f'./result/{args.optimizer}_alpha{args.alpha}_lr{args.lr}_bs{args.bs}_rounds{len(test_accs)}_epoch{args.meanE}_{args.localE}_size{args.size}.csv'
results.to_csv(file_name, index = False)

pd.DataFrame(betas).to_csv(f'{file_name}_beta.csv', index=False)

# %% [markdown]
# # raw main func

# %%
# if __name__ == "__main__":
    
    
#     args = args_parser()
#     if not os.path.exists('./log/'+args.exp_name):
#         os.makedirs('./log/'+args.exp_name) # yn modify from mkdir to makedirs
#     #rank = args.rank#the rank of worker,0,because distributed runing, each file has a client id
#     size = args.size #number of local workers,8
#     device = 'cuda:0'
    
    
#     torch.manual_seed(args.seed)
#     torch.cuda.manual_seed(args.seed)
#     torch.backends.cudnn.deterministic = True
    
#     global_model = select_model(10, args).to(device)#10 class classification
#     global_weights = global_model.state_dict()
    
    
#     algorithms = {
#         'fedavg': FedProx, # mu = 0
#         'fedprox': FedProx,
#         # 'scaffold': Scaffold,
#         'fednova': FedNova,
#         # 'fednova_vr':FedNovaVR,
#     }
    
#     selected_opt = algorithms[args.optimizer]
    
#     epochs_array = generate_random_array(size, mean=args.meanE, lower_bound=1, upper_bound=args.localE)
    
#     test_accs,test_losses=[],[]
#     for rnd in range(args.rounds):
#         global_model.train()
#         local_weights=[]
#         gradient_norm =[]
        
#         for rank in range(args.size):
#             train_loader, test_loader, DataRatios = partition_dataset(rank, size, args)
#             local_epochs = epochs_array[rank]
#             print('global round:{:d}, client id={:d}, localE={:d}'.format(rnd, rank, local_epochs))
            
#             local_model = copy.deepcopy(global_model)
#             criterion = nn.CrossEntropyLoss().to(device)
#             optimizer = selected_opt(local_model.parameters(),
#                              lr=args.lr,
#                              gmf=args.gmf,
#                              mu=args.mu,
#                              ratio=DataRatios[rank],
#                              momentum=args.momentum,
#                              nesterov = False,
#                              weight_decay=1e-4)
            
#             update_learning_rate(optimizer, rnd, args.lr)
            
            
#             for t in range(local_epochs):
#                 w, gn=train(local_model, criterion, optimizer, train_loader, t)
#                 local_weights.append(copy.deepcopy(w))
#                 gradient_norm.append(copy.deepcopy(gn))
                
        
#         global_weights = average_weights(local_weights)
#         global_model.load_state_dict(global_weights)
        
#         test_acc, test_loss = evaluate(global_model, 
#                                        test_loader)
#         print('global round:{:d}, test_acc={:.2f}, test_loss={:.4f}'.format(rnd, test_acc, test_loss))
#         test_accs.append(test_acc)
#         test_losses.append(test_loss)
        
#         # save results
#         csvfile = open('./log/'+args.exp_name+'/epoch_acc_loss.csv',"a",newline = "")      #w是覆盖形写入，a是追加写入
#         writer = csv.writer(csvfile)
#         writer.writerow([rnd, test_acc, test_loss])
#         csvfile.close()
